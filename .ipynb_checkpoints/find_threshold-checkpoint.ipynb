# %% [markdown]
# # 评论文本信息抽取

# %%
import os
import time
import csv
import numpy as np
from gensim import corpora, models, similarities
from pprint import pprint

from ngram import nrams
from ngram import ngrams_pos
from preprocess import read_data
from preprocess import segmentation
from rules import rules_filter


# attraction_name = '乐山大佛'
# attraction_name = '白云山'
attraction_name = '闻一多纪念馆'
file_path = '../data/data_reviews/' + attraction_name + '.txt'
stopwords_file = '../data/stopwords/stopwords_marks.txt'
min_count = 1
threshold = 0

# %% [markdown]
# ## 词频汇总统计

# %%
def compute_frequency(file_path=file_path):
    data = []
    rd = read_data.ReadData()
    ws = segmentation.WordSegmentation()
    try:
        for item in rd.generate_data(file_path):
            temp = ws.seg([item])
            data.extend(temp[0])
    except Exception as e:
        print(e)

    return data
    # result = []
    # fw = nrams.FreqPhrase(min_count=1, threshold=0, stopwords_file=stopwords_file)
    # for item, value in fw.combine2words(data).items():
    #     # 景点名，评论数量，频繁子序列，频繁子序列出现次数
    #     # result.append(['test', len(data), ''.join(item), value[0]])
    #     result.append([''.join(item), value[0]])
    # print('result', result)
compute_frequency(file_path)
# Out:
# data ['闻一多', '为', '湖北', '浠水县', '人', '，', '著名', '爱国人士', '我', '在', '实高', '读书', '的', '时候', '去过', '好几回', '，', '不要', '门票', '，', '又', '近', '，', '那', '时候', '周末', '叫', '上', '胡', '季春', '，', '涂文涛', '，', '余翔', '，', '我们', '几个', '就', '一起', '去', '里面', '玩', '，', '看看', '充满', '文化', '气息', '的', '古物', '，', '读读', '秀丽', '典雅', '的', '古文', '，', '也', '是', '别有风味', '。']

# %%
start = time.time()

for file in files:
    file = convert_doc_to_wordlist(file, cut_all=True)
    dictionary.add_documents([file])

print('run time:', time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7bed5e7ed366> in <module>()
#       1 start = time.time()
#       2
# ----> 3 for file in files:
#       4     file = convert_doc_to_wordlist(file, cut_all=True)
#       5     dictionary.add_documents([file])
#
# NameError: name 'files' is not defined

# %%
# 带词性
start = time.time()
count = 0
dictionary = corpora.Dictionary()
for parent, dirnames, filenames in os.walk('/Users/monabai/Desktop/data/pinglun'):
    print(len(filenames))
    result_pos = []
    for filename in filenames:
        attraction_name = filename[:-4]
        if attraction_name != 'pinglun':
            file_path = '/Users/monabai/Desktop/data/pinglun/' + attraction_name + '.txt'
            print(file_path)
            data_pos = []
            rd = read_data.ReadData()
            ws = segmentation.WordSegmentation()
            try:
                for item in rd.generate_data(file_path):
                    temp = ws.seg_pos([item])
                    data_pos.extend(temp[0])
            except Exception as e:
                print(e)
                continue
#             print(type(data_pos))
            print(data_pos)
            count += 1
            dictionary.add_documents([data_pos])
            if count == 1:
                break
#             fw = ngrams_pos.FreqPhrase(min_count=10, threshold=0.4, stopwords_file=stopwords_file)
#             for item, value in fw.combine2words(data_pos).items():
                # 景点名，评论数量，频繁子序列，频繁子序列出现次数
                # result.append(['test', len(data), ''.join(item), value[0]])
#                 result_pos.append([''.join(x.word for x in item), '/'.join(x.flag for x in item), value[0]])
        # with open(output_file, 'w') as f:
        #     csv.writer(f).writerows(result)

print('run time:', time.time()-start)
# Out:
# 35404
# /Users/monabai/Desktop/data/pinglun/顶秀美泉小镇.txt
# [pair('小镇', 'nr'), pair('整体', 'n'), pair('设计', 'vn'), pair('从', 'p'), pair('自然', 'd'), pair('中', 'f'), pair('汲取', 'v'), pair('灵感', 'a'), pair('，', 'x'), pair('以', 'p'), pair('“', 'x'), pair('绿叶', 'n'), pair('”', 'x'), pair('的', 'uj'), pair('叶脉', 'nr'), pair('进行', 'v'), pair('建筑', 'n'), pair('布局', 'n'), pair('及', 'c'), pair('园林设计', 'n'), pair('，', 'x'), pair('开发', 'v'), pair('则', 'd'), pair('根据', 'p'), pair('周边环境', 'l'), pair('望山', 'nr'), pair('、', 'x'), pair('近', 'a'), pair('水', 'n'), pair('以及', 'c'), pair('地块', 'n'), pair('内', 'n'), pair('原有', 'v'), pair('树林', 'n'), pair('、', 'x'), pair('原有', 'v'), pair('溪流', 'n'), pair('的', 'uj'), pair('特点', 'n'), pair('；', 'x'), pair('以', 'p'), pair('尊重', 'a'), pair('自然', 'd'), pair('、', 'x'), pair('融入', 'v'), pair('自然', 'd'), pair('的', 'uj'), pair('设计', 'vn'), pair('理念', 'n'), pair('，', 'x'), pair('依据', 'p'), pair('山', 'n'), pair('－', 'x'), pair('水', 'n'), pair('－', 'x'), pair('树', 'v'), pair('－', 'x'), pair('小镇', 'nr'), pair('的', 'uj'), pair('设计', 'vn'), pair('思想', 'n'), pair('，', 'x'), pair('充分', 'ad'), pair('营造', 'vn'), pair('出', 'v'), pair('欧式', 'n'), pair('风情', 'n'), pair('的', 'uj'), pair('低层', 'n'), pair('低密度', 'n'), pair('、', 'x'), pair('类', 'q'), pair('别墅', 'n'), pair('的', 'uj'), pair('情趣', 'n'), pair('空间', 'n'), pair('。', 'x'), pair('从', 'p'), pair('怀柔', 'nr'), pair('回来', 'v'), pair('路过', 'v'), pair('这里', 'r'), pair('，', 'x'), pair('是', 'v'), pair('个', 'q'), pair('欧洲', 'ns'), pair('风格', 'n'), pair('小镇', 'nr'), pair('。', 'x'), pair('从', 'p'), pair('怀柔', 'nr'), pair('回来', 'v'), pair('路过', 'v'), pair('这里', 'r'), pair('，', 'x'), pair('是', 'v'), pair('个', 'q'), pair('欧洲', 'ns'), pair('风格', 'n'), pair('小镇', 'nr'), pair('。', 'x'), pair('国庆', 't'), pair('期间', 'f'), pair('自驾', 'v'), pair('过来', 't'), pair('的', 'uj'), pair('人', 'n'), pair('不少', 'd'), pair(' ', 'x'), pair('但', 'c'), pair('也', 'd'), pair('不显', 'a'), pair('拥挤', 'v'), pair(' ', 'x'), pair('适合', 'v'), pair('拍拍', 'v'), pair('照', 'n'), pair(' ', 'x'), pair('呼吸', 'v'), pair('新鲜空气', 'nt'), pair(' ', 'x'), pair('这边', 'r'), pair('其实', 'd'), pair('就是', 'd'), pair('一个', 'm'), pair('小区', 'n'), pair(' ', 'x'), pair('开发商', 'n'), pair('修', 'v'), pair('的', 'uj'), pair('比较', 'd'), pair('好', 'a'), pair('有种', 'r'), pair('欧洲', 'ns'), pair('风格', 'n'), pair(' ', 'x'), pair(' ', 'x'), pair('也', 'd'), pair('有', 'v'), pair('吃饭', 'v'), pair('的', 'uj'), pair('地方', 'n'), pair('第一', 'm'), pair('去', 'v'), pair('欧洲', 'ns'), pair('小镇', 'nr'), pair('，', 'x'), pair('真的', 'd'), pair('有种', 'r'), pair('去', 'v'), pair('了', 'ul'), pair('欧洲', 'ns'), pair('的', 'uj'), pair('感觉', 'n'), pair('住', 'v'), pair('在', 'p'), pair('小镇', 'nr'), pair('里', 'f'), pair('的', 'uj'), pair('酒店', 'n'), pair('也', 'd'), pair('整体', 'n'), pair('欧式', 'n'), pair('风格', 'n'), pair('，', 'x'), pair('傍晚', 't'), pair('在', 'p'), pair('小镇', 'nr'), pair('的', 'uj'), pair('酒吧街', 'n'), pair('喝', 'vg'), pair('了', 'ul'), pair('一杯', 'm'), pair('很', 'zg'), pair('舒服', 'a'), pair('很', 'zg'), pair('享受', 'v'), pair('那样', 'r'), pair('的慢', 'd'), pair('生活', 'vn'), pair('。', 'x'), pair('假期', 't'), pair('跟', 'p'), pair('朋友', 'n'), pair('一起', 'm'), pair('去', 'v'), pair('玩', 'v'), pair('的', 'uj'), pair('，', 'x'), pair('住', 'v'), pair('了', 'ul'), pair('几晚', 'd'), pair(' ', 'x'), pair('感觉', 'n'), pair('还', 'd'), pair('不错', 'a'), pair('，', 'x'), pair('客房', 'n'), pair('配置', 'v'), pair('也', 'd'), pair('很', 'd'), pair('齐全', 'nr'), pair(' ', 'x'), pair(' ', 'x'), pair('街景', 'n'), pair('很漂亮', 'n'), pair(' ', 'x'), pair('在', 'p'), pair('那里', 'r'), pair('吃', 'v'), pair('了', 'ul'), pair('一顿', 'm'), pair('露天', 'v'), pair('烧烤', 'v'), pair(' ', 'x'), pair('特别', 'd'), pair('棒', 'zg'), pair('！', 'x'), pair('周末', 't'), pair('带', 'v'), pair('孩子', 'n'), pair('住', 'v'), pair('过', 'ug'), pair('那个', 'r'), pair('茜', 'nr'), pair('茜', 'nr'), pair('酒店', 'n'), pair('，', 'x'), pair('真心', 'd'), pair('不错', 'a'), pair('。', 'x'), pair('晚上', 't'), pair('还', 'd'), pair('可以', 'c'), pair('在', 'p'), pair('小镇', 'nr'), pair('里面', 'f'), pair('溜达', 'v'), pair( ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-fe74bee56027> in <module>()
#      24             print(data_pos)
#      25             count += 1
# ---> 26             dictionary.add_documents([data_pos])
#      27             if count == 1:
#      28                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/corpora/dictionary.py in add_documents(self, documents, prune_at)
#     196
#     197             # update Dictionary with the document
# --> 198             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     199
#     200         logger.info(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/corpora/dictionary.py in doc2bow(self, document, allow_update, return_missing)
#     239         counter = defaultdict(int)
#     240         for w in document:
# --> 241             counter[w if isinstance(w, unicode) else unicode(w, 'utf-8')] += 1
#     242
#     243         token2id = self.token2id
#
# TypeError: decoding to str: need a bytes-like object, pair found

# %%
# 不带词性
start = time.time()
count = 0
dictionary = corpora.Dictionary()
for parent, dirnames, filenames in os.walk('/Users/monabai/Desktop/data/pinglun'):
    print(len(filenames))
    result = []
    for filename in filenames:
        attraction_name = filename[:-4]
        if attraction_name != 'pinglun':
            file_path = '/Users/monabai/Desktop/data/pinglun/' + attraction_name + '.txt'
            print(file_path)
            data = []
            rd = read_data.ReadData()
            ws = segmentation.WordSegmentation()
            try:
                for item in rd.generate_data(file_path):
                    if item:
                        temp = ws.seg([item])
                        data.extend(temp[0])
            except Exception as e:
                print(e)
                continue
#             print(data)
            count += 1
            dictionary.add_documents([data])
            if count == 5:
                break
#             fw = ngrams_pos.FreqPhrase(min_count=10, threshold=0.4, stopwords_file=stopwords_file)
#             for item, value in fw.combine2words(data_pos).items():
                # 景点名，评论数量，频繁子序列，频繁子序列出现次数
                # result.append(['test', len(data), ''.join(item), value[0]])
#                 result_pos.append([''.join(x.word for x in item), '/'.join(x.flag for x in item), value[0]])
        # with open(output_file, 'w') as f:
        #     csv.writer(f).writerows(result)

print('run time:', time.time()-start)
dictionary.save('../data/corpus/test.dict')
# Out:
# 35404
# /Users/monabai/Desktop/data/pinglun/顶秀美泉小镇.txt
# /Users/monabai/Desktop/data/pinglun/北京邵飘萍故居.txt
# /Users/monabai/Desktop/data/pinglun/黎明洞.txt
# /Users/monabai/Desktop/data/pinglun/老虎潭.txt
# /Users/monabai/Desktop/data/pinglun/观象山.txt
# run time: 0.1429901123046875

# %%
dictionary.load('../data/corpus/test.dict')
print(dictionary)
# print(dictionary.keys())    #返回所有词语的编号
# print(dictionary.dfs)    #{单词id，在多少文档中出现}
# print(dictionary.get(5)) #返回编号对应的词语，例如这里5->特性。
# print(dictionary.compactify()) #压缩词语向量，如果使用了filter_extremes，filter_n_most_frequent，filter_tokens等删除词典元素的操作，可以使用该方法进行压缩
# print(dictionary.num_docs) #所有文章数目
# print(dictionary.num_nnz) #每个文件中不重复词个数的和
# print(dictionary.num_pos) #所有词的个数
for key in dictionary.keys():
    print(key,dictionary.get(key),dictionary.dfs[key])
# Out:
# Dictionary(1152 unique tokens: [' ', '!', '.', '..', '...']...)
# 0   3
# 1 ! 1
# 2 . 1
# 3 .. 1
# 4 ... 1
# 5 0 1
# 6 10 1
# 7 13 1
# 8 6 1
# 9 666 1
# 10 LOFT 1
# 11 XD 1
# 12 p 1
# 13 ~ 2
# 14 “ 2
# 15 ” 2
# 16 … 1
# 17 、 3
# 18 。 4
# 19 一 1
# 20 一下 2
# 21 一个 2
# 22 一些 3
# 23 一回 1
# 24 一圈 1
# 25 一定 2
# 26 一家 2
# 27 一座 2
# 28 一晚 1
# 29 一杯 1
# 30 一样 3
# 31 一次 1
# 32 一点 2
# 33 一眼 1
# 34 一般 3
# 35 一起 2
# 36 一顿 1
# 37 上 3
# 38 上周末 1
# 39 上班族 1
# 40 下 1
# 41 下雨 1
# 42 不 2
# 43 不少 1
# 44 不是 3
# 45 不显 1
# 46 不用 1
# 47 不至于 1
# 48 不错 3
# 49 两种 1
# 50 个 2
# 51 个人 2
# 52 个人感觉 1
# 53 中 2
# 54 中世纪 1
# 55 中哇 1
# 56 临时 1
# 57 之前 1
# 58 也 3
# 59 了 4
# 60 交通 2
# 61 享受 1
# 62 京郊 1
# 63 亲子 1
# 64 人 2
# 65 人不太多 1
# 66 人性化 1
# 67 人民 2
# 68 今年 1
# 1062 花钱 1
# 1063 落叶 1
# 1064 落寞 1
# 1065 蓝天 1
# 1066 蔬菜 1
# 1067 虽然 1
# 1068 行程 1
# 1069 街巷 1
# 1070 要来 1
# 1071 要重 1
# 1072 观 1
# 1073 观天象 1
# 1074 观想 1
# 1075 观景 1
# 1076 观景台 1
# 1077 观测室 1
# 1078 观看 1
# 1079 观象 1
# 1080 观象台 1
# 1081 观长 1
# 1082 觉得 1
# 1083 认识 1
# 1084 讨喜 1
# 1085 让 1
# 1086 许多条 1
# 1087 试 1
# 1088 语 1
# 1089 说实话 1
# 1090 谈天 1
# 1091 象山 1
# 1092 走向 1
# 1093 赶 1
# 1094 起码 1
# 1095 足够 1
# 1096 跟着 1
# 1097 路 1
# 1098 路上 1
# 1099 辛苦 1
# 1100 过去 1
# 1101 近代 1
# 1102 还种 1
# 1103 远景 1
# 1104 远眺 1
# 1105 透 1
# 1106 通向 1
# 1107 遛弯 1
# 1108 遛狗 1
# 1109 那儿 1
# 1110 那种 1
# 1111 那组 1
# 1112 里头 1
# 1113 里边 1
# 1114 重要 1
# 1115 钱 1
# 1116 铺满 1
# 1117 锻炼 1
# 1118 门票 1
# 1119 问 1
# 1120 闲逛 1
# 1121 间 1
# 1122 闹市区 1
# 1123 随意 1
# 1124 隐居 1
# 1125 难得 1
# 1126 难忘 1
# 1127 雨 1
# 1128 零 1
# 1129 零零散散 1
# 1130 青岛 1
# 1131 青岛市 1
# 1132 青年 1
# 1133 青旅 1
# 1134 非常 1
# 1135 顺着 1
# 1136 领着 1
# 1137 额 1
# 1138 风景 1
# 1139 饭 1
# 1140 驻地 1
# 1141 骗 1
# 1142 骗人 1
# 1143 高 1
# 1144 高点 1
# 1145 麦岛 1
# 1146 黄昏 1
# 1147 黑 1
# 1148 默默 1
# 1149 鼻子 1
# 1150 ： 1
# 1151 ～ 1

# %% [markdown]
# ## TF-IDF汇总统计

# %%
print(os.getcwd())
# Out:
# /Users/monabai/Bonjour/InformationRetrieval/InfoR

# %% [markdown]
# ## 词性汇总统计

# %%
start = time.time()
data_pos = []    # 带有词性标注的分词结果
result_pos = []  # 带有词性标注的频繁子序列
rd = read_data.ReadData()
ws = segmentation.WordSegmentation()
try:
    for item in rd.generate_data(file_path):
        temp = ws.seg_pos([item])
        data_pos.append(temp[0])
        # break
except Exception as e:
    print(e)
# print(data_pos)
# fw = ngrams_pos.FreqPhrase(min_count=1, threshold=0, stopwords_file=stopwords_file)
# count = 0
# for item, value in fw.combine2words(data_pos).items():
#     count += 1
#     # 景点名，评论数量，频繁子序列，频繁子序列出现次数
#     # result.append(['test', len(data), ''.join(item), value[0]])
#     result_pos.append([''.join(x.word for x in item), '/'.join(x.flag for x in item), value[0]])
print('run time:', time.time() - start)
# print(result_pos)
# print('频繁子序列的个数：', count)

# count_final = 0
# result_final = []
# pf = rules_filter.pos_filter()
# for item in result_pos:
#     pos = item[1].split('/')
#     if pf.pos_refuse(pos):
#         continue
#     else:
#         count_final += 1
#         result_final.append(item)
# # print(result_final)
# print('频繁子序列的个数：', count_final)
# Out:
# run time: 0.010968208312988281
